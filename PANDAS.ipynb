# %%
import pandas as pd

# %%
mydata = {
    'cars' : ['BMW','VOLVO','FORD'],
    'passing' : [3,2,6]
}

myvar = pd.DataFrame(mydata)
print(myvar)
# Out:
#     cars  passing
# 0    BMW        3
# 1  VOLVO        2
# 2   FORD        6

# %%
print(pd.__version__)
# Out:
# 1.4.2

# %%
import pandas as pd

a = [2,9,5]

my_var = pd.Series(a)
print(my_var)
# Out:
# 0    2
# 1    9
# 2    5
# dtype: int64

# %%
 b = [5,3,7]

tar_ta = pd.Series(b,index=["r","t","z"])
print(tar_ta)
print(tar_ta["z"])
# Out:
# r    5
# t    3
# z    7
# dtype: int64
# 7

# %%
tel = myvar.loc[1]
print(tel)
# Out:
# cars       VOLVO
# passing        2
# Name: 1, dtype: object

# %%
tel1 = myvar.loc[[0,1,2]]
print(tel1)
# Out:
#     cars  passing
# 0    BMW        3
# 1  VOLVO        2
# 2   FORD        6

# %%
myvar = pd.DataFrame(mydata, index = [11,22,33])
print(myvar)
# Out:
#      cars  passing
# 11    BMW        3
# 22  VOLVO        2
# 33   FORD        6

# %%
print(myvar.to_string())
# Out:
#      cars  passing
# 11    BMW        3
# 22  VOLVO        2
# 33   FORD        6

# %%
print(myvar.loc[33])
# Out:
# cars       FORD
# passing       6
# Name: 33, dtype: object

# %%
re = pd.read_csv("data.csv")
print(re)
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
print(re.head())
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
print(re.head(10))
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
# 5  BMW    1 Series  2012  premium unleaded (required)      230.0
# 6  BMW    1 Series  2012  premium unleaded (required)      300.0
# 7  BMW    1 Series  2012  premium unleaded (required)      300.0
# 8  BMW    1 Series  2012  premium unleaded (required)      230.0
# 9  BMW    1 Series  2013  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# ...

# %%
print(re.tail())
# Out:
#           Make   Model  Year                Engine Fuel Type  Engine HP  \
# 11909    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
# ...

# %%
print(re.tail(4))
# Out:
#           Make   Model  Year                Engine Fuel Type  Engine HP  \
# 11910    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
#                   Market Category Vehicle Size  Vehicle Style  highway MPG  \
# 11910  Crossover,Hatchback,Luxury      Midsize  4dr Hatchback           23
# ...

# %%
print(pd.options.display.max_rows)
# Out:
# 60

# %%
import numpy as np

# %%
ne = pd.read_csv("C:\\Users\\DEll\\Downloads\\Household-living-costs-price-indexes-September-2022-quarter-group-facts.csv")
print(ne)
# Out:
#                         hlpi_name  year   hlpi  tot_hhs      own  own_wm  \
# 0                  All households  2008  allhh  1560859  1087580  574406
# 1                     Beneficiary  2008  benef   185965    71256   39405
# 2         Income quintile 1 (low)  2008  disq1   312376   191470   48424
# 3               Income quintile 2  2008  disq2   312333   196203   84171
# 4               Income quintile 3  2008  disq3   312240   217657  141318
# ..                            ...   ...    ...      ...      ...     ...
# 65         Expenditure quintile 3  2020  expq3   352564   213893  119637
# 66         Expenditure quintile 4  2020  expq4   350182   235256  141104
# 67  Expenditure quintile 5 (high)  2020  expq5   351328   288779  187838
# 68                          Māori  2020  maori   329588   156459  107753
# 69                 Superannuitant  2020  super   388013   314154   38270
#
#     own_prop  own_wm_prop  prop_hhs   age  size  income  expenditure  \
# ...

# %%
ne.head()
# Out:
#                  hlpi_name  year   hlpi  tot_hhs      own  own_wm  own_prop  \
# 0           All households  2008  allhh  1560859  1087580  574406      69.7
# 1              Beneficiary  2008  benef   185965    71256   39405      38.3
# 2  Income quintile 1 (low)  2008  disq1   312376   191470   48424      61.3
# 3        Income quintile 2  2008  disq2   312333   196203   84171      62.8
# 4        Income quintile 3  2008  disq3   312240   217657  141318      69.7
#
#    own_wm_prop  prop_hhs   age  size  income  expenditure  eqv_income  eqv_exp
# 0         36.8     100.0  35.9   2.7   46704        42394       26869    25132
# 1         21.2      11.9  29.9   2.6   23404        25270       14258    15824
# 2         15.5      20.0  40.0   2.3   16747        21145       13402    14408
# 3         26.9      20.0  34.7   2.8   31308        29855       18917    18266
# 4         45.3      20.0  31.5   3.0   49106        46561       26870    24672

# %%
ne.tail()
# Out:
#                         hlpi_name  year   hlpi  tot_hhs     own  own_wm  \
# 65         Expenditure quintile 3  2020  expq3   352564  213893  119637
# 66         Expenditure quintile 4  2020  expq4   350182  235256  141104
# 67  Expenditure quintile 5 (high)  2020  expq5   351328  288779  187838
# 68                          Māori  2020  maori   329588  156459  107753
# 69                 Superannuitant  2020  super   388013  314154   38270
#
#     own_prop  own_wm_prop  prop_hhs   age  size  income  expenditure  \
# 65      60.7         33.9      20.1  36.9   2.8   69779        57351
# 66      67.2         40.3      19.9  35.0   3.0   88944        83038
# 67      82.2         53.5      20.0  39.6   2.6  104277       123424
# 68      47.5         32.7      18.8  31.1   3.2   69581        54141
# 69      81.0          9.9      22.1  69.8   1.7   34712        34643
#
#     eqv_income  eqv_exp
# 65       38889    33468
# 66       48929    45978
# 67       62718    71985
# ...

# %%
ne.isnull()
# Out:
#     hlpi_name   year   hlpi  tot_hhs    own  own_wm  own_prop  own_wm_prop  \
# 0       False  False  False    False  False   False     False        False
# 1       False  False  False    False  False   False     False        False
# 2       False  False  False    False  False   False     False        False
# 3       False  False  False    False  False   False     False        False
# 4       False  False  False    False  False   False     False        False
# ..        ...    ...    ...      ...    ...     ...       ...          ...
# 65      False  False  False    False  False   False     False        False
# 66      False  False  False    False  False   False     False        False
# 67      False  False  False    False  False   False     False        False
# 68      False  False  False    False  False   False     False        False
# 69      False  False  False    False  False   False     False        False
#
#     prop_hhs    age   size  income  expenditure  eqv_income  eqv_exp
# ...

# %%
print(ne.isnull().sum())
# Out:
# hlpi_name      0
# year           0
# hlpi           0
# tot_hhs        0
# own            0
# own_wm         0
# own_prop       0
# own_wm_prop    0
# prop_hhs       0
# age            0
# size           0
# income         0
# expenditure    0
# eqv_income     0
# eqv_exp        0
# dtype: int64

# %%
we = pd.read_csv('C:\\Users\\DEll\\Downloads\\National-labour-force-projections-2020base-2073.csv.csv')
print(we)
# Out:
#      year Characteristic       P05        P25     P50     P75     P95  \
# 0    2020      not avail      2860  not avail  2904.0  2922.0  2950.0
# 1    2023          totlf  no value       2916  2963.0  3011.0  3073.0
# 2    2028          totlf      2874       3016  3110.0  3208.0  3356.0
# 3    2033          totlf      2899       3099  3239.0  3387.0  3598.0
# 4    2038          totlf      2941       3175  3343.0  3528.0  3810.0
# ..    ...            ...       ...        ...     ...     ...     ...
# 271  2053           tahw        33         36    38.0    39.0    42.0
# 272  2058           tahw        33         36    38.0    40.0    42.0
# 273  2063           tahw        32         35    37.0    40.0    43.0
# 274  2068           tahw        32         35    37.0    40.0    43.0
# 275  2073           tahw        32         35    37.0    40.0    43.0
#
#      sortorder
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ..         ...
# ...

# %%
print(we.loc[[0,1,2]])
# Out:
#    year Characteristic       P05        P25     P50     P75     P95  sortorder
# 0  2020      not avail      2860  not avail  2904.0  2922.0  2950.0          1
# 1  2023          totlf  no value       2916  2963.0  3011.0  3073.0          1
# 2  2028          totlf      2874       3016  3110.0  3208.0  3356.0          1

# %%
print(we.isnull())
# Out:
#       year  Characteristic    P05    P25    P50    P75    P95  sortorder
# 0    False           False  False  False  False  False  False      False
# 1    False           False  False  False  False  False  False      False
# 2    False           False  False  False  False  False  False      False
# 3    False           False  False  False  False  False  False      False
# 4    False           False  False  False  False  False  False      False
# ..     ...             ...    ...    ...    ...    ...    ...        ...
# 271  False           False  False  False  False  False  False      False
# 272  False           False  False  False  False  False  False      False
# 273  False           False  False  False  False  False  False      False
# 274  False           False  False  False  False  False  False      False
# 275  False           False  False  False  False  False  False      False
#
# [276 rows x 8 columns]

# %%
print(we.isnull().sum())
# Out:
# year              0
# Characteristic    0
# P05               2
# P25               2
# P50               2
# P75               2
# P95               2
# sortorder         0
# dtype: int64

# %%
print(we.isnull().sum().sum())
# Out:
# 10

# %%
# NaN = no value, not available
# NA 
# NULL

# %%
print(we.notnull())
# Out:
#      year  Characteristic   P05   P25   P50   P75   P95  sortorder
# 0    True            True  True  True  True  True  True       True
# 1    True            True  True  True  True  True  True       True
# 2    True            True  True  True  True  True  True       True
# 3    True            True  True  True  True  True  True       True
# 4    True            True  True  True  True  True  True       True
# ..    ...             ...   ...   ...   ...   ...   ...        ...
# 271  True            True  True  True  True  True  True       True
# 272  True            True  True  True  True  True  True       True
# 273  True            True  True  True  True  True  True       True
# 274  True            True  True  True  True  True  True       True
# 275  True            True  True  True  True  True  True       True
#
# [276 rows x 8 columns]

# %%
print(we.notnull().sum())
# Out:
# year              276
# Characteristic    276
# P05               274
# P25               274
# P50               274
# P75               274
# P95               274
# sortorder         276
# dtype: int64

# %%
print(we.notnull().sum().sum())
# Out:
# 2198

# %%
print(we.dropna()) #drop row(by default) of null value
# Out:
#      year Characteristic     P05     P25     P50     P75     P95  sortorder
# 0    2020          totlf  2860.0  2886.0  2904.0  2922.0  2950.0          1
# 1    2023          totlf  2858.0  2916.0  2963.0  3011.0  3073.0          1
# 2    2028          totlf  2874.0  3016.0  3110.0  3208.0  3356.0          1
# 3    2033          totlf  2899.0  3099.0  3239.0  3387.0  3598.0          1
# 4    2038          totlf  2941.0  3175.0  3343.0  3528.0  3810.0          1
# ..    ...            ...     ...     ...     ...     ...     ...        ...
# 271  2053           tahw    33.0    36.0    38.0    39.0    42.0         23
# 272  2058           tahw    33.0    36.0    38.0    40.0    42.0         23
# 273  2063           tahw    32.0    35.0    37.0    40.0    43.0         23
# 274  2068           tahw    32.0    35.0    37.0    40.0    43.0         23
# 275  2073           tahw    32.0    35.0    37.0    40.0    43.0         23
#
# [274 rows x 8 columns]

# %%
print(we.dropna(axis = 1)) # drop column of null values , if we replace 1 with o then it will drop row of null values
# Out:
#      year Characteristic  sortorder
# 0    2020      not avail          1
# 1    2023          totlf          1
# 2    2028          totlf          1
# 3    2033          totlf          1
# 4    2038          totlf          1
# ..    ...            ...        ...
# 271  2053           tahw         23
# 272  2058           tahw         23
# 273  2063           tahw         23
# 274  2068           tahw         23
# 275  2073           tahw         23
#
# [276 rows x 3 columns]

# %%
print(we.dropna(axis = 0).head(14)) # it will droped row with null values till first 14 rows
# Out:
#     year Characteristic     P05     P25     P50     P75     P95  sortorder
# 2   2028          totlf  2874.0  3016.0  3110.0  3208.0  3356.0          1
# 3   2033          totlf  2899.0  3099.0  3239.0  3387.0  3598.0          1
# 4   2038          totlf  2941.0  3175.0  3343.0  3528.0  3810.0          1
# 5   2043          totlf  2950.0  3226.0  3434.0  3656.0  4012.0          1
# 6   2048          totlf  2914.0  3285.0  3515.0  3775.0  4143.0          1
# 7   2053          totlf  2897.0  3313.0  3578.0  3876.0  4280.0          1
# 8   2058          totlf  2882.0  3318.0  3621.0  3933.0  4424.0          1
# 9   2063          totlf  2823.0  3315.0  3654.0  3994.0  4557.0          1
# 10  2068          totlf  2797.0  3318.0  3683.0  4057.0  4667.0          1
# 11  2073          totlf  2754.0  3299.0  3704.0  4107.0  4738.0          1
# 13  2023      anngrowth   -27.0     4.0    26.0    46.0    81.0          2
# ...

# %%
print(we.head(15))
# Out:
#     year Characteristic     P05     P25     P50     P75     P95  sortorder
# 0   2020      not avail  2860.0     NaN  2904.0  2922.0  2950.0          1
# 1   2023          totlf     NaN  2916.0  2963.0  3011.0  3073.0          1
# 2   2028          totlf  2874.0  3016.0  3110.0  3208.0  3356.0          1
# 3   2033          totlf  2899.0  3099.0  3239.0  3387.0  3598.0          1
# 4   2038          totlf  2941.0  3175.0  3343.0  3528.0  3810.0          1
# 5   2043          totlf  2950.0  3226.0  3434.0  3656.0  4012.0          1
# 6   2048          totlf  2914.0  3285.0  3515.0  3775.0  4143.0          1
# 7   2053          totlf  2897.0  3313.0  3578.0  3876.0  4280.0          1
# 8   2058          totlf  2882.0  3318.0  3621.0  3933.0  4424.0          1
# 9   2063          totlf  2823.0  3315.0  3654.0  3994.0  4557.0          1
# 10  2068          totlf  2797.0  3318.0  3683.0  4057.0  4667.0          1
# ...

# %%
we = pd.read_csv('C:\\Users\\DEll\\Downloads\\National-labour-force-projections-2020base-2073.csv.csv',na_values = ["not avail","no value"])
print(we)  # it will give NaN for values mentioned in list
# Out:
#      year Characteristic     P05     P25     P50     P75     P95  sortorder
# 0    2020            NaN  2860.0     NaN  2904.0  2922.0  2950.0          1
# 1    2023          totlf     NaN  2916.0  2963.0  3011.0  3073.0          1
# 2    2028          totlf  2874.0  3016.0  3110.0  3208.0  3356.0          1
# 3    2033          totlf  2899.0  3099.0  3239.0  3387.0  3598.0          1
# 4    2038          totlf  2941.0  3175.0  3343.0  3528.0  3810.0          1
# ..    ...            ...     ...     ...     ...     ...     ...        ...
# 271  2053           tahw    33.0    36.0    38.0    39.0    42.0         23
# 272  2058           tahw    33.0    36.0    38.0    40.0    42.0         23
# 273  2063           tahw    32.0    35.0    37.0    40.0    43.0         23
# 274  2068           tahw    32.0    35.0    37.0    40.0    43.0         23
# 275  2073           tahw    32.0    35.0    37.0    40.0    43.0         23
#
# [276 rows x 8 columns]

# %%
we = pd.read_csv('C:\\Users\\DEll\\Downloads\\National-labour-force-projections-2020base-2073.csv.csv',na_values = {"P25" :"not avail","P05": "no value"})
print(we) # it will give NaN for column mentioned in dict
# Out:
#      year Characteristic     P05     P25     P50     P75     P95  sortorder
# 0    2020      not avail  2860.0     NaN  2904.0  2922.0  2950.0          1
# 1    2023          totlf     NaN  2916.0  2963.0  3011.0  3073.0          1
# 2    2028          totlf  2874.0  3016.0  3110.0  3208.0  3356.0          1
# 3    2033          totlf  2899.0  3099.0  3239.0  3387.0  3598.0          1
# 4    2038          totlf  2941.0  3175.0  3343.0  3528.0  3810.0          1
# ..    ...            ...     ...     ...     ...     ...     ...        ...
# 271  2053           tahw    33.0    36.0    38.0    39.0    42.0         23
# 272  2058           tahw    33.0    36.0    38.0    40.0    42.0         23
# 273  2063           tahw    32.0    35.0    37.0    40.0    43.0         23
# 274  2068           tahw    32.0    35.0    37.0    40.0    43.0         23
# 275  2073           tahw    32.0    35.0    37.0    40.0    43.0         23
#
# [276 rows x 8 columns]

# %%
we.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 276 entries, 0 to 275
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            276 non-null    int64
#  1   Characteristic  276 non-null    object
#  2   P05             273 non-null    float64
#  3   P25             273 non-null    float64
#  4   P50             274 non-null    float64
#  5   P75             274 non-null    float64
#  6   P95             274 non-null    float64
#  7   sortorder       276 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 17.4+ KB

# %%
dn = we.dropna(inplace = False)
print(dn)
print(dn.to_string())
# Out:
#      year Characteristic     P05     P25     P50     P75     P95  sortorder
# 2    2028          totlf  2874.0  3016.0  3110.0  3208.0  3356.0          1
# 3    2033          totlf  2899.0  3099.0  3239.0  3387.0  3598.0          1
# 4    2038          totlf  2941.0  3175.0  3343.0  3528.0  3810.0          1
# 5    2043          totlf  2950.0  3226.0  3434.0  3656.0  4012.0          1
# 6    2048          totlf  2914.0  3285.0  3515.0  3775.0  4143.0          1
# ..    ...            ...     ...     ...     ...     ...     ...        ...
# 271  2053           tahw    33.0    36.0    38.0    39.0    42.0         23
# 272  2058           tahw    33.0    36.0    38.0    40.0    42.0         23
# 273  2063           tahw    32.0    35.0    37.0    40.0    43.0         23
# 274  2068           tahw    32.0    35.0    37.0    40.0    43.0         23
# 275  2073           tahw    32.0    35.0    37.0    40.0    43.0         23
#
# [272 rows x 8 columns]
# ...

# %%
import pandas as pd 
import numpy as np 
print(np.std([4,7,2,1,6,3]))
# Out:
# 2.1147629234082532

# %%
fn = we.fillna(130,inplace = False)
print(fn)
# Out:
#      year Characteristic     P05     P25     P50     P75     P95  sortorder
# 0    2020            130  2860.0   130.0  2904.0  2922.0  2950.0          1
# 1    2023          totlf   130.0  2916.0  2963.0  3011.0  3073.0          1
# 2    2028          totlf  2874.0  3016.0  3110.0  3208.0  3356.0          1
# 3    2033          totlf  2899.0  3099.0  3239.0  3387.0  3598.0          1
# 4    2038          totlf  2941.0  3175.0  3343.0  3528.0  3810.0          1
# ..    ...            ...     ...     ...     ...     ...     ...        ...
# 271  2053           tahw    33.0    36.0    38.0    39.0    42.0         23
# 272  2058           tahw    33.0    36.0    38.0    40.0    42.0         23
# 273  2063           tahw    32.0    35.0    37.0    40.0    43.0         23
# 274  2068           tahw    32.0    35.0    37.0    40.0    43.0         23
# 275  2073           tahw    32.0    35.0    37.0    40.0    43.0         23
#
# [276 rows x 8 columns]

# %%
import pandas as pd

# %%
w_e = pd.read_csv('C:\\Users\\DEll\\Downloads\\National-labour-force-projections-2020base-2073.csv.csv',na_values = ["not avail","no value"])
print(w_e.to_string())
# Out:
#      year Characteristic     P05     P25     P50     P75     P95  sortorder
# 0    2020            NaN  2860.0     NaN  2904.0  2922.0  2950.0          1
# 1    2023          totlf     NaN  2916.0  2963.0  3011.0  3073.0          1
# 2    2028          totlf  2874.0  3016.0  3110.0  3208.0  3356.0          1
# 3    2033          totlf  2899.0  3099.0  3239.0  3387.0  3598.0          1
# 4    2038          totlf  2941.0  3175.0  3343.0  3528.0  3810.0          1
# 5    2043          totlf  2950.0  3226.0  3434.0  3656.0  4012.0          1
# 6    2048          totlf  2914.0  3285.0  3515.0  3775.0  4143.0          1
# 7    2053          totlf  2897.0  3313.0  3578.0  3876.0  4280.0          1
# 8    2058          totlf  2882.0  3318.0  3621.0  3933.0  4424.0          1
# 9    2063          totlf  2823.0  3315.0  3654.0  3994.0  4557.0          1
# 10   2068          totlf  2797.0  3318.0  3683.0  4057.0  4667.0          1
# ...

# %%
y = w_e['P25'].mode()

w_e['P25'].fillna(y,inplace = True)

print(w_e.to_string())
# Out:
#      year Characteristic          P05     P25     P50     P75     P95  sortorder
# 0    2020       age15_24  2860.000000    42.0  2904.0  2922.0  2950.0          1
# 1    2023          totlf   262.168498  2916.0  2963.0  3011.0  3073.0          1
# 2    2028          totlf  2874.000000  3016.0  3110.0  3208.0  3356.0          1
# 3    2033          totlf  2899.000000  3099.0  3239.0  3387.0  3598.0          1
# 4    2038          totlf  2941.000000  3175.0  3343.0  3528.0  3810.0          1
# 5    2043          totlf  2950.000000  3226.0  3434.0  3656.0  4012.0          1
# 6    2048          totlf  2914.000000  3285.0  3515.0  3775.0  4143.0          1
# 7    2053          totlf  2897.000000  3313.0  3578.0  3876.0  4280.0          1
# 8    2058          totlf  2882.000000  3318.0  3621.0  3933.0  4424.0          1
# 9    2063          totlf  2823.000000  3315.0  3654.0  3994.0  4557.0          1
# 10   2068          totlf  2797.000000  3318.0  3683.0  4057.0  4667.0          1
# ...

# %%
import pandas as pd

# %%
ex = pd.read_excel("C:\\Users\\DEll\\Desktop\\tabtrial.xlsx")
print(ex)
# Out:
#     name                 date         city  marks
# 0  tanvi  2003-02-05 00:00:00    ahmedabad     34
# 1  rahul            23/5/2001        surat      0
# 2  sneha  2000-10-02 00:00:00   himatnagar     68
# 3   axay  2003-02-06 00:00:00      mehsana     98
# 4  payal            23/5/2002  gandhinagar     68

# %%
ex["date"] = pd.to_datetime(ex["date"])
print(ex.to_string())
# Out:
#     name       date         city  marks
# 0  tanvi 2003-02-05    ahmedabad     34
# 1  rahul 2001-05-23        surat      0
# 2  sneha 2000-10-02   himatnagar     68
# 3   axay 2003-02-06      mehsana     98
# 4  payal 2002-05-23  gandhinagar     68
